# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

rolling_period = 20

def read_system_json(algo, env, scenario, env_n, seed):
    seed = f"seed_{seed}"
    path = f"../results/json/{algo}/{env}/{scenario}/envs_{env_n}/{seed}/"
    try:
        with open(path + "metrics.json", "r") as f:
            data = json.load(f)
    except:
        print(f"Failed to read {path}")
        return None

    data = data[env][scenario][algo][seed]
    records = {}
    for key in data.keys():
        n = key.split("_")[1]
        if len(n) > 3: continue # skip abs metric
        entry = {"mean_episode_returns": data[key]["mean_episode_returns"][0]}
        records[int(n)] = entry
    df = pd.DataFrame.from_dict(records, orient="index")
    if len(df) == 0: return None
    # TODO: this method provides a lagging rolling mean, I need to change it to provide a RT mean
    df[f"rolling_20"] = df["mean_episode_returns"].rolling(20, min_periods=1).mean()
    df[f"rolling_10"] = df["mean_episode_returns"].rolling(10, min_periods=1).mean()
    
    return df

# %%
env = "HeuristicEnemySMAX"
scenario = "2s3z"

env_ns = [1, 2, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ff_ippo", env, scenario, env_n, seed)

        if df is None: continue
        
        df.plot(y="mean_episode_returns", alpha=0.2, ax=ax, color=colors[i])
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax, color=colors[i])

        i += 1

# %%
env = "HeuristicEnemySMAX"
scenario = "2s3z"

env_ns = [1, 2, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ff_ippo_ewma", env, scenario, env_n, seed)

        if df is None: continue
        
        df.plot(y="mean_episode_returns", alpha=0.2, ax=ax, color=colors[i])
        df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax, color=colors[i])

        i += 1
# Out:
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_2/seed_42/
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_16/seed_42/
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_32/seed_42/

# %%
env = "HeuristicEnemySMAX"
scenario = "2s3z"

env_ns = [1, 2, 4, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

ax = plt.gca()

i = 0
for env_n in env_ns:
    for seed in seeds:
        df = read_system_json("ff_ippo", env, scenario, env_n, seed)

        if df is not None: 
            df.plot(y="rolling_20", label=f"ppo_{env_n}_{seed}", ax=ax, color=colors[i])

        df = read_system_json("ff_ippo_ewma", env, scenario, env_n, seed)

        if df is not None: 
            df.plot(y="rolling_20", label=f"ppo_ewma_{env_n}_{seed}", ax=ax, color=colors[i])
        


        i += 1
# Out:
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_1/seed_42/
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_2/seed_42/
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_16/seed_42/
# Failed to read ../results/json/ff_ippo_ewma/HeuristicEnemySMAX/2s3z/envs_32/seed_42/

# %%
env = "HeuristicEnemySMAX"
scenario = "2s3z"

env_ns = [1, 2, 4, 8, 16, 32]
seeds = [42]
colors = ['blue', "orange", 'green', 'red', 'yellow', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

# ax = plt.gca()
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize=(12, 10))

i = 0
for env_n in env_ns:
    for seed in seeds:
        ax = axs[i//3][i%3]
        df = read_system_json("ff_ippo_ewma", env, scenario, env_n, seed)
        if df is not None:
            df.plot(y="rolling_20", label=f"ippo_ewma_{env_n}_{seed}", ax=ax)

        df = read_system_json("ff_ippo", env, scenario, env_n, seed)
        if df is not None:
            df.plot(y="rolling_20", label=f"ippo_{env_n}_{seed}", ax=ax)

        ax.grid(True)
        ax.set_title(f"env_{env_n}_{seed}")
        # ax.set_ylim(30, 135)

        ax.set_ylim(0.2, 1.6)


        i += 1
